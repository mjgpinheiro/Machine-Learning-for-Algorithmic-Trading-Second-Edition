# %% [markdown]
# <a href="https://colab.research.google.com/github/mjgpinheiro/Machine-Learning-for-Algorithmic-Trading-Second-Edition/blob/master/Machine_Learning_Stocks_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import pandas as pd
import numpy as np
# !pip install talib-binary
# !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz 
# !ls
# !tar xvzf ta-lib-0.4.0-src.tar.gz
import os
os.chdir('ta-lib') # Can't use !cd in co-lab
# !./configure --prefix=/usr
# !make
# !make install
# wait ~ 30s
os.chdir('../')
# !pip install TA-Lib
# !pip install backtrader
import talib
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from backtrader import Strategy, cerebro
from backtrader.feeds import PandasData

# Collect data
# !pip install yfinance
import yfinance as yf

# Get historical market data for AAPL from Yahoo Finance
aapl = yf.Ticker("AAPL")

# Get historical data for the past year
aapl_history = aapl.history(period="1y")
import pandas as pd
import yfinance as yf

# Get historical market data for AAPL from Yahoo Finance
aapl = yf.Ticker("AAPL")

# Get historical data for the past year
aapl_history = aapl.history(period="1y")

# Read the data into a Pandas DataFrame
data = pd.DataFrame(aapl_history)

# Access the 'Open', 'High', 'Low', 'Close', and 'Volume' columns
open_prices = data['Open']
high_prices = data['High']
low_prices = data['Low']
close_prices = data['Close']
volume = data['Volume']

# Print the first 5 rows of the DataFrame
print(data.head())

#data = pd.read_csv('stock_data.csv')

# Preprocess data
data = data.dropna()
data = data.reset_index(drop=True)

# Feature engineering
data['MA20'] = talib.SMA(data['Close'].values, timeperiod=20)
data['RSI'] = talib.RSI(data['Close'].values, timeperiod=14)

# Develop AI strategy
X = data[['MA20', 'RSI']]
X = data[['MA20', 'RSI']].fillna(method='ffill')
import numpy as np
from sklearn.linear_model import LinearRegression

# assume X and y are your input data and target variable, respectively

# handle missing values by filling them with the mean of the column
X = X.fillna(X.mean())

# handle infinite values by replacing them with a large value
X[np.isinf(X)] = np.finfo('float32').max

# handle very large values by scaling the data to a smaller range
X = X / np.max(np.abs(X))

# create a LinearRegression model and call the fit method
#model = LinearRegression()
#model.fit(X, y)


#y = np.all(np.isnan(data['Close']), 1,-1)
y = np.where(data['Close'].shift(-1) > data['Close'], 1, -1)
#y = np.any(np.isnan(data['Close'].shift(-1)) > np.isnan(data['Close']), axis=1)
#y = np.all(np.isnan(data['Close']), 1,-1)
model = DecisionTreeClassifier()
model.fit(X, y)

# Train AI model
X_train, y_train = X[:-100], y[:-100]
X_test, y_test = X[-100:], y[-100:]
model.fit(X_train, y_train)

# Backtest AI model
# !pip install backtrader
import backtrader as bt
from datetime import datetime

class MyStrategy(bt.Strategy):
    params = (
        ('fast', 20),
        ('slow', 50),
    )

    def __init__(self):
        self.sma_fast = bt.indicators.SimpleMovingAverage(
            self.data.close, period=self.params.fast)
        self.sma_slow = bt.indicators.SimpleMovingAverage(
            self.data.close, period=self.params.slow)

    def next(self):
        if not self.position:
            if self.sma_fast[0] > self.sma_slow[0]:
                self.buy()
        elif self.sma_fast[0] < self.sma_slow[0]:
            self.sell()

import backtrader as bt
import yfinance as yf
from datetime import datetime

# Define the start and end dates
start_date = datetime(2020, 1, 1)
end_date = datetime(2021, 1, 1)

# Download the data using yfinance
data = yf.download('AAPL', start=start_date, end=end_date)

# Convert the data to a Backtrader data feed
data = bt.feeds.PandasData(dataname=data)

# Create a cerebro instance and add the data feed
cerebro = bt.Cerebro()
cerebro.adddata(data)

# Run the backtest
cerebro.run()


# Evaluate performance
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement talib-binary (from versions: none)
# ERROR: No matching distribution found for talib-binary
# --2023-02-19 14:54:23--  http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# Resolving prdownloads.sourceforge.net (prdownloads.sourceforge.net)... 204.68.111.105
# Connecting to prdownloads.sourceforge.net (prdownloads.sourceforge.net)|204.68.111.105|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz [following]
# --2023-02-19 14:54:23--  http://downloads.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz
# Resolving downloads.sourceforge.net (downloads.sourceforge.net)... 204.68.111.105
# Reusing existing connection to prdownloads.sourceforge.net:80.
# ...
